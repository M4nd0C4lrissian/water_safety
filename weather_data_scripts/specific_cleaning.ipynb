# %%
import pandas as pd
import numpy as np

# %%
## need to pad with 0s where toronto city has nans for snow on ground - or do we even need that? We can also consider using
## toronto city centre - I think we can remove the flags too

# %%
df = pd.read_csv('cleaned_data\daily\\merged_toronto_hanlans.csv', index_col=0)

# %%
df.describe()
# Out:
#              eColi   statusFlag         Year        Month          Day  \
# count  1522.000000  1522.000000  1522.000000  1522.000000  1522.000000
# mean     29.224047     0.045335  2015.603154     7.122208    15.603154
# std      43.640985     0.208106     5.139238     0.878283     8.963814
# min       8.000000     0.000000  2007.000000     5.000000     1.000000
# 25%      11.000000     0.000000  2011.000000     6.000000     8.000000
# 50%      16.000000     0.000000  2016.000000     7.000000    15.500000
# 75%      28.000000     0.000000  2020.000000     8.000000    23.000000
# max     696.000000     1.000000  2024.000000     9.000000    31.000000
#
#        Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# count    1506.000000    1507.000000     1504.000000         1504.000000
# mean       26.115339      17.205242       21.671210            0.207713
# std         3.634208       3.038905        3.117271            0.755970
# ...

# %%
df.columns
# Out:
# Index(['CollectionDate', 'eColi', 'statusFlag', 'Date/Time', 'Year', 'Month',
#        'Day', 'Max Temp (°C)', 'Max Temp Flag', 'Min Temp (°C)',
#        'Min Temp Flag', 'Mean Temp (°C)', 'Mean Temp Flag',
#        'Heat Deg Days (°C)', 'Heat Deg Days Flag', 'Cool Deg Days (°C)',
#        'Cool Deg Days Flag', 'Total Precip (mm)'],
#       dtype='object')

# %%
df.head()
# Out:
#   CollectionDate  eColi  statusFlag   Date/Time  Year  Month  Day  \
# 0     2007-06-03     10           0  2007-06-03  2007      6    3
# 1     2007-06-04     10           0  2007-06-04  2007      6    4
# 2     2007-06-05     70           0  2007-06-05  2007      6    5
# 3     2007-06-06    159           1  2007-06-06  2007      6    6
# 4     2007-06-07     23           1  2007-06-07  2007      6    7
#
#    Max Temp (°C) Max Temp Flag  Min Temp (°C) Min Temp Flag  Mean Temp (°C)  \
# 0           25.1           NaN           17.1           NaN            21.1
# 1           22.7           NaN           15.4           NaN            19.1
# 2           19.3           NaN            7.4           NaN            13.4
# 3           17.3           NaN            8.1           NaN            12.7
# 4           20.3           NaN           11.4           NaN            15.9
#
#   Mean Temp Flag  Heat Deg Days (°C) Heat Deg Days Flag  Cool Deg Days (°C)  \
# ...

# %%
# df['Snow on Grnd (cm)'] = df['Snow on Grnd (cm)'].fillna(0)

# %%
df.describe()
# Out:
#              eColi   statusFlag         Year        Month          Day  \
# count  1522.000000  1522.000000  1522.000000  1522.000000  1522.000000
# mean     29.224047     0.045335  2015.603154     7.122208    15.603154
# std      43.640985     0.208106     5.139238     0.878283     8.963814
# min       8.000000     0.000000  2007.000000     5.000000     1.000000
# 25%      11.000000     0.000000  2011.000000     6.000000     8.000000
# 50%      16.000000     0.000000  2016.000000     7.000000    15.500000
# 75%      28.000000     0.000000  2020.000000     8.000000    23.000000
# max     696.000000     1.000000  2024.000000     9.000000    31.000000
#
#        Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# count    1506.000000    1507.000000     1504.000000         1504.000000
# mean       26.115339      17.205242       21.671210            0.207713
# std         3.634208       3.038905        3.117271            0.755970
# ...

# %%
df.drop(columns=['Max Temp Flag', 'Min Temp Flag', 'Mean Temp Flag', 'Heat Deg Days Flag', 'Cool Deg Days Flag'], inplace=True)

# %%
df.head()
# Out:
#   CollectionDate  eColi  statusFlag   Date/Time  Year  Month  Day  \
# 0     2007-06-03     10           0  2007-06-03  2007      6    3
# 1     2007-06-04     10           0  2007-06-04  2007      6    4
# 2     2007-06-05     70           0  2007-06-05  2007      6    5
# 3     2007-06-06    159           1  2007-06-06  2007      6    6
# 4     2007-06-07     23           1  2007-06-07  2007      6    7
#
#    Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# 0           25.1           17.1            21.1                 0.0
# 1           22.7           15.4            19.1                 0.0
# 2           19.3            7.4            13.4                 4.6
# 3           17.3            8.1            12.7                 5.3
# 4           20.3           11.4            15.9                 2.1
#
#    Cool Deg Days (°C)  Total Precip (mm)
# 0                 3.1                9.1
# 1                 1.1                2.0
# ...

# %%
df.describe()
# Out:
#              eColi   statusFlag         Year        Month          Day  \
# count  1522.000000  1522.000000  1522.000000  1522.000000  1522.000000
# mean     29.224047     0.045335  2015.603154     7.122208    15.603154
# std      43.640985     0.208106     5.139238     0.878283     8.963814
# min       8.000000     0.000000  2007.000000     5.000000     1.000000
# 25%      11.000000     0.000000  2011.000000     6.000000     8.000000
# 50%      16.000000     0.000000  2016.000000     7.000000    15.500000
# 75%      28.000000     0.000000  2020.000000     8.000000    23.000000
# max     696.000000     1.000000  2024.000000     9.000000    31.000000
#
#        Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# count    1506.000000    1507.000000     1504.000000         1504.000000
# mean       26.115339      17.205242       21.671210            0.207713
# std         3.634208       3.038905        3.117271            0.755970
# ...

# %%
mask = (df['Total Precip (mm)'].isna())
df.drop(df.loc[mask].index, inplace=True)

# %%
df.describe()
# Out:
#              eColi   statusFlag         Year        Month          Day  \
# count  1488.000000  1488.000000  1488.000000  1488.000000  1488.000000
# mean     29.475806     0.046371  2015.604839     7.117608    15.592070
# std      44.076210     0.210358     5.161393     0.880338     9.010544
# min       8.000000     0.000000  2007.000000     5.000000     1.000000
# 25%      11.000000     0.000000  2011.000000     6.000000     8.000000
# 50%      16.000000     0.000000  2016.000000     7.000000    16.000000
# 75%      28.000000     0.000000  2020.000000     8.000000    23.000000
# max     696.000000     1.000000  2024.000000     9.000000    31.000000
#
#        Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# count    1487.000000    1488.000000     1487.000000         1487.000000
# mean       26.116073      17.198387       21.672360            0.209482
# std         3.636451       3.041090        3.121975            0.759762
# ...

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#              eColi   statusFlag         Year        Month          Day  \
# count  1488.000000  1488.000000  1488.000000  1488.000000  1488.000000
# mean     29.475806     0.046371  2015.604839     7.117608    15.592070
# std      44.076210     0.210358     5.161393     0.880338     9.010544
# min       8.000000     0.000000  2007.000000     5.000000     1.000000
# 25%      11.000000     0.000000  2011.000000     6.000000     8.000000
# 50%      16.000000     0.000000  2016.000000     7.000000    16.000000
# 75%      28.000000     0.000000  2020.000000     8.000000    23.000000
# max     696.000000     1.000000  2024.000000     9.000000    31.000000
#
#        Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# count    1488.000000    1488.000000     1488.000000         1488.000000
# mean       26.098522      17.198387       21.657796            0.209341
# std         3.697735       3.041090        3.171092            0.759526
# ...

# %%
df.head()
# Out:
#   CollectionDate  eColi  statusFlag   Date/Time  Year  Month  Day  \
# 0     2007-06-03     10           0  2007-06-03  2007      6    3
# 1     2007-06-04     10           0  2007-06-04  2007      6    4
# 2     2007-06-05     70           0  2007-06-05  2007      6    5
# 3     2007-06-06    159           1  2007-06-06  2007      6    6
# 4     2007-06-07     23           1  2007-06-07  2007      6    7
#
#    Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# 0           25.1           17.1            21.1                 0.0
# 1           22.7           15.4            19.1                 0.0
# 2           19.3            7.4            13.4                 4.6
# 3           17.3            8.1            12.7                 5.3
# 4           20.3           11.4            15.9                 2.1
#
#    Cool Deg Days (°C)  Total Precip (mm)
# 0                 3.1                9.1
# 1                 1.1                2.0
# ...

# %%
df.drop(columns=['Year', 'Month', 'Day', 'CollectionDate'], inplace=True)

# %%
df.head()
# Out:
#    eColi  statusFlag   Date/Time  Max Temp (°C)  Min Temp (°C)  \
# 0     10           0  2007-06-03           25.1           17.1
# 1     10           0  2007-06-04           22.7           15.4
# 2     70           0  2007-06-05           19.3            7.4
# 3    159           1  2007-06-06           17.3            8.1
# 4     23           1  2007-06-07           20.3           11.4
#
#    Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  Total Precip (mm)
# 0            21.1                 0.0                 3.1                9.1
# 1            19.1                 0.0                 1.1                2.0
# 2            13.4                 4.6                 0.0                1.8
# 3            12.7                 5.3                 0.0                0.0
# 4            15.9                 2.1                 0.0                0.0

# %%
df.to_csv('cleaned_data\daily\\cleaned_merged_toronto_city_hanlans.csv')
